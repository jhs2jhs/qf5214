# %% [markdown]
# This notebook is designed for QF5214 workshop 1.
#
# You can download this into your computing environment.

# %% [markdown]
# # Part 1: stock signalling

# %% [markdown]
# ### install dependency
# uncomment bellow commands and run if you have not install bellow dependency

# %%
from platform import python_version
print(python_version())
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
# Out:
# 3.10.12
# /root/qf5214/qf/bin/python
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# sys.version_info(major=3, minor=10, micro=12, releaselevel='final', serial=0)

# %%
# !pip3 install pandas
# !pip3 install numpy
# !pip3 install yfinance
# !pip3 install bt
# !pip3 install matplotlib
# !pip3 install seaborn
# !pip3 install future
# !pip3 install ffn
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: pandas in ./qf/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in ./qf/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./qf/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./qf/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./qf/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in ./qf/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: numpy in ./qf/lib/python3.10/site-packages (1.26.4)
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: yfinance in ./qf/lib/python3.10/site-packages (0.2.36)
# Requirement already satisfied: pandas>=1.3.0 in ./qf/lib/python3.10/site-packages (from yfinance) (2.2.0)
# Requirement already satisfied: numpy>=1.16.5 in ./qf/lib/python3.10/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in ./qf/lib/python3.10/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in ./qf/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in ./qf/lib/python3.10/site-packages (from yfinance) (5.1.0)
# Requirement already satisfied: appdirs>=1.4.4 in ./qf/lib/python3.10/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in ./qf/lib/python3.10/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in ./qf/lib/python3.10/site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in ./qf/lib/python3.10/site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./qf/lib/python3.10/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in ./qf/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in ./qf/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in ./qf/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in ./qf/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./qf/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in ./qf/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./qf/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./qf/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./qf/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./qf/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Collecting bt
#   Using cached bt-1.0.0-cp310-cp310-linux_x86_64.whl
# Requirement already satisfied: ffn>=1.0.0 in ./qf/lib/python3.10/site-packages (from bt) (1.0.1)
# Collecting pyprind>=2.11 (from bt)
#   Downloading http://mirrors.aliyun.com/pypi/packages/ab/b3/1f12ebc5009c65b607509393ad98240728b4401bc3593868fb161fdd3760/PyPrind-2.11.3-py2.py3-none-any.whl (8.4 kB)
# Requirement already satisfied: decorator>=5.0.7 in ./qf/lib/python3.10/site-packages (from ffn>=1.0.0->bt) (5.1.1)
# Requirement already satisfied: matplotlib>=1 in ./qf/lib/python3.10/site-packages (from ffn>=1.0.0->bt) (3.8.3)
# Requirement already satisfied: numpy>=1.5 in ./qf/lib/python3.10/site-packages (from ffn>=1.0.0->bt) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in ./qf/lib/python3.10/site-packages (from ffn>=1.0.0->bt) (2.2.0)
# Requirement already satisfied: pandas-datareader>=0.2 in ./qf/lib/python3.10/site-packages (from ffn>=1.0.0->bt) (0.10.0)
# Requirement already satisfied: scikit-learn>=0.15 in ./qf/lib/python3.10/site-packages (from ffn>=1.0.0->bt) (1.4.1.post1)
# Requirement already satisfied: scipy>=0.15 in ./qf/lib/python3.10/site-packages (from ffn>=1.0.0->bt) (1.12.0)
# Requirement already satisfied: tabulate>=0.7.5 in ./qf/lib/python3.10/site-packages (from ffn>=1.0.0->bt) (0.9.0)
# Requirement already satisfied: yfinance>=0.2 in ./qf/lib/python3.10/site-packages (from ffn>=1.0.0->bt) (0.2.36)
# Requirement already satisfied: contourpy>=1.0.1 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn>=1.0.0->bt) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn>=1.0.0->bt) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn>=1.0.0->bt) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn>=1.0.0->bt) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn>=1.0.0->bt) (23.2)
# Requirement already satisfied: pillow>=8 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn>=1.0.0->bt) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn>=1.0.0->bt) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn>=1.0.0->bt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./qf/lib/python3.10/site-packages (from pandas>=0.19->ffn>=1.0.0->bt) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./qf/lib/python3.10/site-packages (from pandas>=0.19->ffn>=1.0.0->bt) (2024.1)
# Requirement already satisfied: lxml in ./qf/lib/python3.10/site-packages (from pandas-datareader>=0.2->ffn>=1.0.0->bt) (5.1.0)
# Requirement already satisfied: requests>=2.19.0 in ./qf/lib/python3.10/site-packages (from pandas-datareader>=0.2->ffn>=1.0.0->bt) (2.31.0)
# Requirement already satisfied: joblib>=1.2.0 in ./qf/lib/python3.10/site-packages (from scikit-learn>=0.15->ffn>=1.0.0->bt) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./qf/lib/python3.10/site-packages (from scikit-learn>=0.15->ffn>=1.0.0->bt) (3.3.0)
# Requirement already satisfied: multitasking>=0.0.7 in ./qf/lib/python3.10/site-packages (from yfinance>=0.2->ffn>=1.0.0->bt) (0.0.11)
# Requirement already satisfied: appdirs>=1.4.4 in ./qf/lib/python3.10/site-packages (from yfinance>=0.2->ffn>=1.0.0->bt) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in ./qf/lib/python3.10/site-packages (from yfinance>=0.2->ffn>=1.0.0->bt) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in ./qf/lib/python3.10/site-packages (from yfinance>=0.2->ffn>=1.0.0->bt) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./qf/lib/python3.10/site-packages (from yfinance>=0.2->ffn>=1.0.0->bt) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in ./qf/lib/python3.10/site-packages (from yfinance>=0.2->ffn>=1.0.0->bt) (1.1)
# Requirement already satisfied: soupsieve>1.2 in ./qf/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2->ffn>=1.0.0->bt) (2.5)
# Requirement already satisfied: six>=1.9 in ./qf/lib/python3.10/site-packages (from html5lib>=1.1->yfinance>=0.2->ffn>=1.0.0->bt) (1.16.0)
# Requirement already satisfied: webencodings in ./qf/lib/python3.10/site-packages (from html5lib>=1.1->yfinance>=0.2->ffn>=1.0.0->bt) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./qf/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn>=1.0.0->bt) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./qf/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn>=1.0.0->bt) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./qf/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn>=1.0.0->bt) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./qf/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn>=1.0.0->bt) (2024.2.2)
# Installing collected packages: pyprind, bt
# Successfully installed bt-1.0.0 pyprind-2.11.3
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: matplotlib in ./qf/lib/python3.10/site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./qf/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./qf/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./qf/lib/python3.10/site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./qf/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in ./qf/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in ./qf/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in ./qf/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./qf/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./qf/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./qf/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Collecting seaborn
#   Downloading http://mirrors.aliyun.com/pypi/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./qf/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in ./qf/lib/python3.10/site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./qf/lib/python3.10/site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./qf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./qf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./qf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./qf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./qf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in ./qf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./qf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./qf/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./qf/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./qf/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in ./qf/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Collecting future
#   Using cached future-0.18.3-py3-none-any.whl
# Installing collected packages: future
# Successfully installed future-0.18.3
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: ffn in ./qf/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: decorator>=5.0.7 in ./qf/lib/python3.10/site-packages (from ffn) (5.1.1)
# Requirement already satisfied: matplotlib>=1 in ./qf/lib/python3.10/site-packages (from ffn) (3.8.3)
# Requirement already satisfied: numpy>=1.5 in ./qf/lib/python3.10/site-packages (from ffn) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in ./qf/lib/python3.10/site-packages (from ffn) (2.2.0)
# Requirement already satisfied: pandas-datareader>=0.2 in ./qf/lib/python3.10/site-packages (from ffn) (0.10.0)
# Requirement already satisfied: scikit-learn>=0.15 in ./qf/lib/python3.10/site-packages (from ffn) (1.4.1.post1)
# Requirement already satisfied: scipy>=0.15 in ./qf/lib/python3.10/site-packages (from ffn) (1.12.0)
# Requirement already satisfied: tabulate>=0.7.5 in ./qf/lib/python3.10/site-packages (from ffn) (0.9.0)
# Requirement already satisfied: yfinance>=0.2 in ./qf/lib/python3.10/site-packages (from ffn) (0.2.36)
# Requirement already satisfied: contourpy>=1.0.1 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn) (23.2)
# Requirement already satisfied: pillow>=8 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./qf/lib/python3.10/site-packages (from matplotlib>=1->ffn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./qf/lib/python3.10/site-packages (from pandas>=0.19->ffn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./qf/lib/python3.10/site-packages (from pandas>=0.19->ffn) (2024.1)
# Requirement already satisfied: lxml in ./qf/lib/python3.10/site-packages (from pandas-datareader>=0.2->ffn) (5.1.0)
# Requirement already satisfied: requests>=2.19.0 in ./qf/lib/python3.10/site-packages (from pandas-datareader>=0.2->ffn) (2.31.0)
# Requirement already satisfied: joblib>=1.2.0 in ./qf/lib/python3.10/site-packages (from scikit-learn>=0.15->ffn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./qf/lib/python3.10/site-packages (from scikit-learn>=0.15->ffn) (3.3.0)
# Requirement already satisfied: multitasking>=0.0.7 in ./qf/lib/python3.10/site-packages (from yfinance>=0.2->ffn) (0.0.11)
# Requirement already satisfied: appdirs>=1.4.4 in ./qf/lib/python3.10/site-packages (from yfinance>=0.2->ffn) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in ./qf/lib/python3.10/site-packages (from yfinance>=0.2->ffn) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in ./qf/lib/python3.10/site-packages (from yfinance>=0.2->ffn) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./qf/lib/python3.10/site-packages (from yfinance>=0.2->ffn) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in ./qf/lib/python3.10/site-packages (from yfinance>=0.2->ffn) (1.1)
# Requirement already satisfied: soupsieve>1.2 in ./qf/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2->ffn) (2.5)
# Requirement already satisfied: six>=1.9 in ./qf/lib/python3.10/site-packages (from html5lib>=1.1->yfinance>=0.2->ffn) (1.16.0)
# Requirement already satisfied: webencodings in ./qf/lib/python3.10/site-packages (from html5lib>=1.1->yfinance>=0.2->ffn) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./qf/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./qf/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./qf/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./qf/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader>=0.2->ffn) (2024.2.2)

# %% [markdown]
# ### import library

# %%
# import python utility libraries
import os as os
import datetime as dt
import itertools as it
from pprint import pprint

# import python data libraries
import pandas as pd

# import the pandas financial data reader library
import yfinance as yf # a similar library is #from yahoofinancials import YahooFinancials
yf.pdr_override()  # make sure we can access Yahoo! Finance

# import the Python bt backtest library
import bt as bt

# import the matplotlib and seaborn visualization library
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /tmp/ipykernel_2948/2277600240.py:8: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import ffn
import ffn.core
ffn.core.GroupStats
# Out:
# ffn.core.GroupStats

# %%
# create a place to store data locally
if not os.path.exists('./datasets'): os.makedirs('./datasets')

# %% [markdown]
# ### download stock history data from yahoo

# %%
# check Apple Stock metadata

aapl = yf.Ticker("AAPL")

# get all stock info
pprint(aapl.info)
# Out:
# {'52WeekChange': 0.22784209,
#  'SandP52WeekChange': 0.25222528,
#  'address1': 'One Apple Park Way',
#  'ask': 181.99,
#  'askSize': 1000,
#  'auditRisk': 4,
#  'averageDailyVolume10Day': 52079360,
#  'averageVolume': 53397922,
#  'averageVolume10days': 52079360,
#  'beta': 1.312,
#  'bid': 181.95,
#  'bidSize': 1000,
#  'boardRisk': 1,
#  'bookValue': 4.793,
#  'city': 'Cupertino',
#  'companyOfficers': [{'age': 62,
#                       'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Mr. Timothy D. Cook',
#                       'title': 'CEO & Director',
#                       'totalPay': 16239562,
#                       'unexercisedValue': 0,
#                       'yearBorn': 1961},
#                      {'age': 60,
#                       'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Mr. Luca  Maestri',
#                       'title': 'CFO & Senior VP',
#                       'totalPay': 4612242,
#                       'unexercisedValue': 0,
#                       'yearBorn': 1963},
#                      {'age': 59,
#                       'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Mr. Jeffrey E. Williams',
#                       'title': 'Chief Operating Officer',
#                       'totalPay': 4637585,
#                       'unexercisedValue': 0,
#                       'yearBorn': 1964},
#                      {'age': 59,
#                       'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Ms. Katherine L. Adams',
#                       'title': 'Senior VP, General Counsel & Secretary',
#                       'totalPay': 4618064,
#                       'unexercisedValue': 0,
#                       'yearBorn': 1964},
#                      {'age': 56,
#                       'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': "Ms. Deirdre  O'Brien",
#                       'title': 'Senior Vice President of Retail',
#                       'totalPay': 4613369,
#                       'unexercisedValue': 0,
#                       'yearBorn': 1967},
#                      {'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Mr. Chris  Kondo',
#                       'title': 'Senior Director of Corporate Accounting',
#                       'unexercisedValue': 0},
#                      {'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Mr. James  Wilson',
#                       'title': 'Chief Technology Officer',
#                       'unexercisedValue': 0},
#                      {'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Suhasini  Chandramouli',
#                       'title': 'Director of Investor Relations',
#                       'unexercisedValue': 0},
#                      {'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Mr. Greg  Joswiak',
#                       'title': 'Senior Vice President of Worldwide Marketing',
#                       'unexercisedValue': 0},
#                      {'age': 49,
#                       'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Mr. Adrian  Perica',
#                       'title': 'Head of Corporate Development',
#                       'unexercisedValue': 0,
#                       'yearBorn': 1974}],
#  'compensationAsOfEpochDate': 1703980800,
#  'compensationRisk': 6,
#  'country': 'United States',
#  'currency': 'USD',
#  'currentPrice': 182.31,
#  'currentRatio': 1.073,
#  'dateShortInterest': 1706659200,
#  'dayHigh': 184.85,
#  'dayLow': 181.665,
#  'debtToEquity': 145.803,
#  'dividendRate': 0.96,
#  'dividendYield': 0.0053,
#  'earningsGrowth': 0.16,
#  'earningsQuarterlyGrowth': 0.131,
#  'ebitda': 130108997632,
#  'ebitdaMargins': 0.33733,
#  'enterpriseToEbitda': 21.906,
#  'enterpriseToRevenue': 7.389,
#  'enterpriseValue': 2850149367808,
#  'exDividendDate': 1707436800,
#  'exchange': 'NMS',
#  'fiftyDayAverage': 189.8614,
#  'fiftyTwoWeekHigh': 199.62,
#  'fiftyTwoWeekLow': 143.9,
#  'financialCurrency': 'USD',
#  'firstTradeDateEpochUtc': 345479400,
#  'fiveYearAvgDividendYield': 0.78,
#  'floatShares': 15414703289,
#  'forwardEps': 6.64,
#  'forwardPE': 27.456326,
#  'freeCashflow': 86563127296,
#  'fullTimeEmployees': 161000,
#  'gmtOffSetMilliseconds': -18000000,
#  'governanceEpochDate': 1706745600,
#  'grossMargins': 0.45027,
#  'heldPercentInsiders': 0.059369996,
#  'heldPercentInstitutions': 0.56646,
#  'impliedSharesOutstanding': 15770500096,
#  'industry': 'Consumer Electronics',
#  'industryDisp': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'lastDividendDate': 1707436800,
#  'lastDividendValue': 0.24,
#  'lastFiscalYearEnd': 1696032000,
#  'lastSplitDate': 1598832000,
#  'lastSplitFactor': '4:1',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets '
#                         'smartphones, personal computers, tablets, wearables, '
#                         'and accessories worldwide. The company offers iPhone, '
#                         'a line of smartphones; Mac, a line of personal '
#                         'computers; iPad, a line of multi-purpose tablets; and '
#                         'wearables, home, and accessories comprising AirPods, '
#                         'Apple TV, Apple Watch, Beats products, and HomePod. '
#                         'It also provides AppleCare support and cloud '
#                         'services; and operates various platforms, including '
#                         'the App Store that allow customers to discover and '
#                         'download applications and digital content, such as '
#                         'books, music, video, games, and podcasts. In '
#                         'addition, the company offers various services, such '
#                         'as Apple Arcade, a game subscription service; Apple '
#                         'Fitness+, a personalized fitness service; Apple '
#                         'Music, which offers users a curated listening '
#                         'experience with on-demand radio stations; Apple '
#                         'News+, a subscription news and magazine service; '
#                         'Apple TV+, which offers exclusive original content; '
#                         'Apple Card, a co-branded credit card; and Apple Pay, '
#                         'a cashless payment service, as well as licenses its '
#                         'intellectual property. The company serves consumers, '
#                         'and small and mid-sized businesses; and the '
#                         'education, enterprise, and government markets. It '
#                         'distributes third-party applications for its products '
#                         'through the App Store. The company also sells its '
#                         'products through its retail and online stores, and '
#                         'direct sales force; and third-party cellular network '
#                         'carriers, wholesalers, retailers, and resellers. '
#                         'Apple Inc. was founded in 1976 and is headquartered '
#                         'in Cupertino, California.',
#  'longName': 'Apple Inc.',
#  'marketCap': 2815212650496,
#  'maxAge': 86400,
#  'messageBoardId': 'finmb_24937',
#  'mostRecentQuarter': 1703894400,
#  'netIncomeToCommon': 100912996352,
#  'nextFiscalYearEnd': 1727654400,
#  'numberOfAnalystOpinions': 39,
#  'open': 183.42,
#  'operatingCashflow': 116433002496,
#  'operatingMargins': 0.33764,
#  'overallRisk': 1,
#  'payoutRatio': 0.14770001,
#  'pegRatio': 2.96,
#  'phone': '408 996 1010',
#  'previousClose': 183.86,
#  'priceHint': 2,
#  'priceToBook': 38.036716,
#  'priceToSalesTrailing12Months': 7.2988563,
#  'profitMargins': 0.26163,
#  'quickRatio': 0.92,
#  'quoteType': 'EQUITY',
#  'recommendationKey': 'buy',
#  'recommendationMean': 2.1,
#  'regularMarketDayHigh': 184.85,
#  'regularMarketDayLow': 181.665,
#  'regularMarketOpen': 183.42,
#  'regularMarketPreviousClose': 183.86,
#  'regularMarketVolume': 49752465,
#  'returnOnAssets': 0.21181,
#  'returnOnEquity': 1.5426899,
#  'revenueGrowth': 0.021,
#  'revenuePerShare': 24.648,
#  'sector': 'Technology',
#  'sectorDisp': 'Technology',
#  'sectorKey': 'technology',
#  'shareHolderRightsRisk': 1,
#  'sharesOutstanding': 15441899520,
#  'sharesPercentSharesOut': 0.0064,
#  'sharesShort': 99244672,
#  'sharesShortPreviousMonthDate': 1703808000,
#  'sharesShortPriorMonth': 108220157,
#  'shortName': 'Apple Inc.',
#  'shortPercentOfFloat': 0.0064,
#  'shortRatio': 1.76,
#  'state': 'CA',
#  'symbol': 'AAPL',
#  'targetHighPrice': 231.93,
#  'targetLowPrice': 146.58,
#  'targetMeanPrice': 186.54,
#  'targetMedianPrice': 185.54,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'totalCash': 73100001280,
#  'totalCashPerShare': 4.734,
#  'totalDebt': 108040003584,
#  'totalRevenue': 385706000384,
#  'trailingAnnualDividendRate': 0.95,
#  'trailingAnnualDividendYield': 0.005166975,
#  'trailingEps': 6.44,
#  'trailingPE': 28.309006,
#  'trailingPegRatio': 2.2441,
#  'twoHundredDayAverage': 183.48035,
#  'underlyingSymbol': 'AAPL',
#  'uuid': '8b10e4ae-9eeb-3684-921a-9ab27e4d87aa',
#  'volume': 49752465,
#  'website': 'https://www.apple.com',
#  'zip': '95014'}

# %%
aapl.institutional_holders
# Out:
#   Date Reported                             Holder  pctHeld      Shares  \
# 0    2023-06-30                 Vanguard Group Inc   0.0834  1303688506
# 1    2023-06-30                     Blackrock Inc.   0.0665  1039640859
# 2    2023-06-30            Berkshire Hathaway, Inc   0.0586   915560382
# 3    2023-06-30           State Street Corporation   0.0370   578897858
# 4    2023-06-30                           FMR, LLC   0.0196   307066638
# 5    2023-06-30      Geode Capital Management, LLC   0.0186   291538165
# 6    2023-06-30      Price (T.Rowe) Associates Inc   0.0145   226650943
# 7    2023-06-30                     Morgan Stanley   0.0131   204714950
# 8    2022-12-31  Norges Bank Investment Management   0.0107   167374278
# 9    2023-06-30         Northern Trust Corporation   0.0105   164536073
#
#           Value
# 0  252876459508
# 1  201659137420
# 2  177591247296
# 3  112288817516
# 4   59561715772
# 5   56549657865
# 6   43963483413
# 7   39708558851
# 8   21746939940
# 9   31915062079

# %%
# set to start and end date of the data download
start_date = dt.datetime(2012, 12, 31)
end_date = dt.datetime(2023, 12, 31)

# download 
tickers_list = ['AAPL']

df_aapl = yf.download(tickers_list, start=start_date, end=end_date, progress=True)
print(df_aapl.head())
fn = './datasets/aapl_stock_%s_%s_daily.csv'%(start_date.year, end_date.year)
df_aapl.to_csv(fn, sep=';', encoding='utf-8')
print('saved to %s'%(fn))
# Out:
# /root/qf5214/qf/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2012-12-31  18.233213  19.121429  18.178572  19.006071  16.233414  659492400
# 2013-01-02  19.779285  19.821428  19.343929  19.608213  16.747726  560518000
# 2013-01-03  19.567142  19.631071  19.321428  19.360714  16.536327  352965200
# 2013-01-04  19.177500  19.236786  18.779642  18.821428  16.075718  594333600
# 2013-01-07  18.642857  18.903570  18.400000  18.710714  15.981156  484156400
# saved to ./datasets/aapl_stock_2012_2023_daily.csv

# %%
# data profiling 
df_aapl.describe(include='all')
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     72.287386    73.072702    71.547797    72.344259    70.290187
# std      56.353171    56.991581    55.762781    56.409949    56.822118
# min      13.856071    14.271429    13.753571    13.947500    11.982237
# 25%      27.567499    27.930000    27.290001    27.575001    25.148233
# 50%      43.810001    44.299999    43.622501    43.955002    41.858551
# 75%     128.949997   130.600006   127.410004   129.610001   127.486725
# max     198.020004   199.619995   197.000000   198.110001   197.857529
#
#              Volume
# count  2.769000e+03
# mean   1.614060e+08
# std    1.239785e+08
# min    2.404830e+07
# 25%    8.426790e+07
# 50%    1.211508e+08
# 75%    1.958040e+08
# max    1.460852e+09

# %%
plt.rcParams['figure.figsize'] = [15, 5]
fig = plt.figure()
ax = fig.add_subplot(111)

# plot aapl stock daily adjusted closing prices
ax.plot(df_aapl.index, df_aapl['Adj Close'], color='#9b59b6')

# rotate x-ticks
for tick in ax.get_xticklabels():
    tick.set_rotation(45)

# set axis labels
ax.set_xlabel('[time]', fontsize=10)
ax.set_xlim([start_date, end_date])
ax.set_ylabel('[adjusted closing price]', fontsize=10)

# set plot title
plt.title('AAPL - Historical Stock Prices', fontsize=10);

# %% [markdown]
# ### feature for moving average crossover strategy
#
# In general, crossover trading refers to the idea that changes of market situations can be determined based on price “breakouts”. A crossover can be interpreted as another measure of a financial instruments momentum. In the past crossover signals have been extensively used to determine that it’s time to either buy or sell the underlying asset.
#
# The price crossover signals of a simple Moving Average Crossover trading strategy are triggered by the following events:
# - Generate a short trading signal once the price of a financial instrument drops below the general price trend, e.g., 100-days moving average band ("Sell Sign Crossover", left image below).
# - Generate a long trading signal once the price of a financial instrument exceeds the general price trend, e.g., 100-days moving average band ("Buy Sign Crossover", right image below).
#
# An enhancement of the Moving Average Crossover is to apply two moving averages to a chart:
# - one long running moving average (e.g., a 200-days SMAV) and one short running moving average (e.g., 20-days SMAV). Once the short running moving average crosses above the long running moving average a Buy or Long signal is triggered, as it indicates that the trend is shifting up (this is known as a "golden cross").
# - On the other hand, when the short running moving average crosses below the long running moving average, a Sell or Short signal is triggered, as it indicates that the trend is shifting down (his is known as a "dead/death cross")

# %%
mav_days_15 = 15  # set "fast" short-running moving average indicator lookback, days = 15
mav_days_60 = 60  # set "slow" short-running moving average indicator lookback, days = 60
mav_days_200 = 200  # set "trend" long-running moving average indicator lookback, days = 200

# %% [markdown]
# Calculate the rolling moving averages of window sizes: 15 days, 50 days and 200 days.
#
# In general the **"Simple Moving Average (SMAV)"** of a financial instrument $i$ (e.g., a stock, commodity, fx-rate) is defined as the mean of the previous $n$ prices, formally denoted by:
#
# $$SMA_{i}(t)=\frac{1}{n} \sum_{k=0}^{n-1} p_{i}(t-k)$$
#
# were $t$ denotes the current point in time and $n$ the lookback.
#
# We can calculate the SMAV by just using the Pandas `rolling()` and `mean()`function:

# %%
smav_15 = pd.Series(df_aapl['Adj Close'].rolling(window = mav_days_15).mean(), name = 'SMAV_15')
smav_60 = pd.Series(df_aapl['Adj Close'].rolling(window = mav_days_60).mean(), name = 'SMAV_60')
smav_200 = pd.Series(df_aapl['Adj Close'].rolling(window = mav_days_200).mean(), name = 'SMAV_200')

# %%
df_smav = df_aapl.join(smav_15)
df_smav = df_smav.join(smav_60)
df_smav = df_smav.join(smav_200)

# %%
df_smav[['Adj Close', 'SMAV_15', 'SMAV_60', 'SMAV_200']].iloc[200:210]
# Out:
#             Adj Close    SMAV_15    SMAV_60   SMAV_200
# Date
# 2013-10-16  15.579005  15.178147  14.916844  14.045211
# 2013-10-17  15.684402  15.216034  14.951498  14.039894
# 2013-10-18  15.820875  15.270211  14.989461  14.036317
# 2013-10-21  16.208557  15.362670  15.032603  14.036981
# 2013-10-22  16.162243  15.428807  15.071474  14.037887
# 2013-10-23  16.320477  15.502177  15.110134  14.039368
# 2013-10-24  16.536551  15.602698  15.152803  14.043183
# 2013-10-25  16.351572  15.691675  15.190253  14.045094
# 2013-10-28  16.473440  15.778993  15.226717  14.048105
# 2013-10-29  16.063061  15.853068  15.252785  14.051893

# %% [markdown]
# ### plot
#
# Plot the historical daily adjusted closing prices (blue) as well as its 15 days (green), 60 days (red) as well as 200 days (yellow) rolling moving averages:

# %%
plt.rcParams['figure.figsize'] = [15, 5]
fig = plt.figure()
ax = fig.add_subplot(111)

# plot adjusted closing prices and moving averages
ax.plot(df_smav['Adj Close'], lw=1.0, color='#9b59b6', label='Closing Prices (purple)')
ax.plot(df_smav['SMAV_15'], color='C1',lw=1.0, label='15-day MAV (green)')
ax.plot(df_smav['SMAV_60'], color='C1',lw=1.0, label='60-day MAV (red)')
ax.plot(df_smav['SMAV_200'], color='C4', lw=1.0, label='200-day MAV (yellow)')

# rotate x-tick labels
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
    
# set axis labels
ax.set_xlabel('[time]', fontsize=10)
ax.set_xlim([start_date, end_date])
ax.set_ylabel('[market price]', fontsize=10)

# set plot legend
plt.legend(loc="upper left", numpoints=1, fancybox=True)

# set plot title
plt.title('AAPL - Daily Historical Stock Closing Prices', fontsize=10);

# %% [markdown]
# ### generate signal
# Derive trading signals from of two distinct moving average crossover trading strategy configurations.
# - We will generate a **long-signal** (+1.0) for the time intervals where the fast moving averages are above the 200-day moving average.
# - In addition we generate a **short-signal** (-1.0) for the time intervals where the fast moving averages are below the 200-day moving average:

# %%
# create 'fast' trend-following signals
df_smav['SIGNAL_15'] = 0.0
df_smav.loc[df_smav['SMAV_15'] > df_smav['SMAV_200'], 'SIGNAL_15'] = 1.0
df_smav.loc[df_smav['SMAV_15'] < df_smav['SMAV_200'], 'SIGNAL_15'] = -1.0

# create 'slow' trend-following signals
df_smav['SIGNAL_60'] = 0.0
df_smav.loc[df_smav['SMAV_60'] > df_smav['SMAV_200'], 'SIGNAL_60'] = 1.0
df_smav.loc[df_smav['SMAV_60'] < df_smav['SMAV_200'], 'SIGNAL_60'] = -1.0

# %%
df_smav['SIGNAL_BASE'] = 1.0

# %%
# convert signals to Pandas DataFrame
df_signal = pd.DataFrame(df_smav[['SIGNAL_15', 'SIGNAL_60', 'SIGNAL_BASE']], columns=['SIGNAL_15', 'SIGNAL_60', 'SIGNAL_BASE'])

# convert pandas DataFrame index to datatype: datetime
df_signal = df_signal.set_index(pd.to_datetime(df_aapl.index))

# %%
df_signal.head(10)
# Out:
#             SIGNAL_15  SIGNAL_60  SIGNAL_BASE
# Date
# 2012-12-31        0.0        0.0          1.0
# 2013-01-02        0.0        0.0          1.0
# 2013-01-03        0.0        0.0          1.0
# 2013-01-04        0.0        0.0          1.0
# 2013-01-07        0.0        0.0          1.0
# 2013-01-08        0.0        0.0          1.0
# 2013-01-09        0.0        0.0          1.0
# 2013-01-10        0.0        0.0          1.0
# 2013-01-11        0.0        0.0          1.0
# 2013-01-14        0.0        0.0          1.0

# %% [markdown]
# Inspect some of the exemplary signal deviations between the 15-days and 60-days crossover moving average trading strategies:

# %%
df_signal[df_signal['SIGNAL_15'] != df_signal['SIGNAL_60']].head(10)
# Out:
#             SIGNAL_15  SIGNAL_60  SIGNAL_BASE
# Date
# 2015-08-11       -1.0        1.0          1.0
# 2015-08-12       -1.0        1.0          1.0
# 2015-08-13       -1.0        1.0          1.0
# 2015-08-14       -1.0        1.0          1.0
# 2015-08-17       -1.0        1.0          1.0
# 2015-08-18       -1.0        1.0          1.0
# 2015-08-19       -1.0        1.0          1.0
# 2015-08-20       -1.0        1.0          1.0
# 2015-08-21       -1.0        1.0          1.0
# 2015-08-24       -1.0        1.0          1.0

# %% [markdown]
# Visualize the prepared trading signals:

# %%
plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(ncols=1, nrows=3)

ax[0].plot(df_signal['SIGNAL_15'], lw=1.0, color='C2', label='SMAV 15 (red)')
ax[1].plot(df_signal['SIGNAL_60'], lw=1.0, color='C1', label='SMAV 60 (green)')
ax[2].plot(df_signal['SIGNAL_BASE'], lw=1.0, color='C3', label='BASE (purple)')
    
# set axis labels
plt.xlabel('[time]', fontsize=10)
ax[0].set_xlim([start_date, end_date])
ax[0].set_ylabel('[smav 15 signal]', fontsize=10)
ax[1].set_xlim([start_date, end_date])
ax[1].set_ylabel('[smav 60 signal]', fontsize=10)
ax[2].set_xlim([start_date, end_date])
ax[2].set_ylabel('[base signal]', fontsize=10)

# rotate the x-axis labels
'''
for tick in ax[0].get_xticklabels():
    tick.set_rotation(45)
    
for tick in ax[1].get_xticklabels():
    tick.set_rotation(45)
    
for tick in ax[2].get_xticklabels():
    tick.set_rotation(45)
'''

# set plot title
ax[0].set_title('AAPL - 15 days Crossover Moving Average Trading Signals', fontsize=10)
ax[1].set_title('AAPL - 60 days Crossover Moving Average Trading Signals', fontsize=10)
ax[2].set_title('AAPL - Baseline Buy and Hold Trading Signals', fontsize=10)

# reset plot layout
plt.tight_layout()

# %% [markdown]
# Let's determine the total number of **long-short signal changes** of the distinct trading strategies:

# %%
# signal changes of the 15-200 days moving average crossover trading strategy
turn_15 = len(list(it.groupby(df_signal['SIGNAL_15'], lambda x: x > 0)))
# signal changes of the 60-200 days moving average crossover trading strategy
turn_60 = len(list(it.groupby(df_signal['SIGNAL_60'], lambda x: x > 0)))
# signal changes of the baseline buy and hold trading strategy
turn_200 = len(list(it.groupby(df_signal['SIGNAL_BASE'], lambda x: x > 0)))

print("tunring points SMAV 15: ", turn_15)
print("tunring points SMAV 60: ", turn_60)
print("tunring points SMAV 200: ", turn_200)
# Out:
# tunring points SMAV 15:  16
# tunring points SMAV 60:  8
# tunring points SMAV 200:  1

# %% [markdown]
# ### signal backtest
#
# Define the moving average trading strategy backtest algorithm stack.
#
# **Note:** That in the Python `bt` library a trading strategy usually consists of a so-called **stack of algorithms**. For each timestep of our backtest timeframe, the `bt` library executes all algorithm of the stack in sequential order. Each moving average strategy we aim to design and backtest consists in total of three algorithms, briefly described in the following:
#
# > 1. `bt.algos.SelectAll()`: Selects all available stocks for trading except stock prices that correspond to NaN or 0.00.
# > 2. `MovingAverageStrategy()`: Assigns the calculated signal in terms of a weight value to the AAPL stock.
# > 3. `bt.algos.Rebalance()`: Rebalances the available capital based on the weights assigned to each stock.

# %%
# extract the AAPL stock closing prices
df_bt = pd.DataFrame(df_aapl['Adj Close'], columns=['Adj Close'])

# rename the 'close' column to 'aapl' (since this is the column we want to allocate to in the backtest)
df_bt = df_bt.rename(columns={'Adj Close': 'aapl'})

# convert pandas DataFrame index to datatype: datetime
df_bt = df_bt.set_index(pd.to_datetime(df_aapl.index))

# %%
df_bt.head(10)
# Out:
#                  aapl
# Date
# 2012-12-31  16.233414
# 2013-01-02  16.747726
# 2013-01-03  16.536327
# 2013-01-04  16.075718
# 2013-01-07  15.981156
# 2013-01-08  16.024164
# 2013-01-09  15.773721
# 2013-01-10  15.969253
# 2013-01-11  15.871337
# 2013-01-14  15.305481

# %%
class MovingAverageStrategy(bt.Algo):
    
    # inits the strategy
    def __init__(self, signals):
        
        # set class signals
        self.signals = signals
        
    # calss the trading strategy
    def __call__(self, target):
        
        # case: current timestep in signals
        if target.now in self.signals.index[1:]:
            
            # get actual signal
            signal = self.signals[target.now]
            
            # set target weights according to signal
            target.temp['weights'] = dict(aapl=signal)
            
        # return 'True' since we want to move on to the next timestep
        return True

# %%
strategy_15 = bt.Strategy(name='smav_15', algos=[bt.algos.SelectAll(), MovingAverageStrategy(df_signal['SIGNAL_15']), bt.algos.Rebalance()])
strategy_60 = bt.Strategy(name='smav_60', algos=[bt.algos.SelectAll(), MovingAverageStrategy(df_signal['SIGNAL_60']), bt.algos.Rebalance()])
strategy_base = bt.Strategy(name='base', algos=[bt.algos.SelectAll(), MovingAverageStrategy(df_signal['SIGNAL_BASE']), bt.algos.Rebalance()])

# %%
# init trading fees function
def trading_fees_function(q, p):
    
    # calcluate trading fees (rebalanced-quantity * trading-fee)
    #fees = q * 0.01 # non-flat fee of 1% per quantity of rebalanced asset
    fees = 5.00 # flat fee of USD 5.00 per trade
    
    # return the total trading fees
    return fees

# %%
bt_15 = bt.Backtest(strategy=strategy_15, data=df_bt, name='backtest_smav_15', commissions=trading_fees_function, progress_bar=True)
bt_60 = bt.Backtest(strategy=strategy_60, data=df_bt, name='backtest_smav_60', commissions=trading_fees_function, progress_bar=True)
bt_base = bt.Backtest(strategy=strategy_base, data=df_bt, name='backtest_smav_base', commissions=trading_fees_function, progress_bar=True)

# %%
backtest_results = bt.run(bt_15, bt_60, bt_base)
# Out:
# backtest_smav_15
# 0% [############################# ] 100% | ETA: 00:00:00backtest_smav_60
# /root/qf5214/qf/lib/python3.10/site-packages/ffn/core.py:191: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   self.monthly_prices = obj.resample("M").last()  # .dropna()
# /root/qf5214/qf/lib/python3.10/site-packages/ffn/core.py:193: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   self.yearly_prices = obj.resample("A").last()  # .dropna()
# 0% [############################# ] 100% | ETA: 00:00:00backtest_smav_base
# /root/qf5214/qf/lib/python3.10/site-packages/ffn/core.py:191: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   self.monthly_prices = obj.resample("M").last()  # .dropna()
# /root/qf5214/qf/lib/python3.10/site-packages/ffn/core.py:193: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   self.yearly_prices = obj.resample("A").last()  # .dropna()
# 0% [############################# ] 100% | ETA: 00:00:00
# /root/qf5214/qf/lib/python3.10/site-packages/ffn/core.py:191: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   self.monthly_prices = obj.resample("M").last()  # .dropna()
# /root/qf5214/qf/lib/python3.10/site-packages/ffn/core.py:193: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   self.yearly_prices = obj.resample("A").last()  # .dropna()
# /root/qf5214/qf/lib/python3.10/site-packages/ffn/core.py:191: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   self.monthly_prices = obj.resample("M").last()  # .dropna()
# /root/qf5214/qf/lib/python3.10/site-packages/ffn/core.py:193: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   self.yearly_prices = obj.resample("A").last()  # .dropna()
# /root/qf5214/qf/lib/python3.10/site-packages/ffn/core.py:191: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   self.monthly_prices = obj.resample("M").last()  # .dropna()
# /root/qf5214/qf/lib/python3.10/site-packages/ffn/core.py:193: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   self.yearly_prices = obj.resample("A").last()  # .dropna()
# /root/qf5214/qf/lib/python3.10/site-packages/ffn/core.py:191: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   self.monthly_prices = obj.resample("M").last()  # .dropna()
# /root/qf5214/qf/lib/python3.10/site-packages/ffn/core.py:193: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   self.yearly_prices = obj.resample("A").last()  # .dropna()

# %%
backtest_results.display()
# Out:
# Stat                 backtest_smav_15    backtest_smav_60    backtest_smav_base
# -------------------  ------------------  ------------------  --------------------
# Start                2012-12-30          2012-12-30          2012-12-30
# End                  2023-12-29          2023-12-29          2023-12-29
# Risk-free rate       0.00%               0.00%               0.00%
#
# Total Return         315.34%             438.32%             1048.11%
# Daily Sharpe         0.61                0.70                0.93
# Daily Sortino        0.99                1.15                1.52
# CAGR                 13.83%              16.54%              24.85%
# Max Drawdown         -49.16%             -50.95%             -38.52%
# Calmar Ratio         0.28                0.32                0.65
#
# MTD                  1.36%               1.36%               1.36%
# 3m                   12.60%              12.60%              12.60%
# 6m                   1.82%               1.82%               1.82%
# YTD                  9.02%               -9.18%              49.01%
# 1Y                   8.75%               -9.40%              49.38%
# 3Y (ann.)            2.68%               1.12%               13.27%
# 5Y (ann.)            7.89%               18.82%              38.50%
# 10Y (ann.)           14.03%              17.02%              27.21%
# Since Incep. (ann.)  13.83%              16.54%              24.85%
#
# Daily Sharpe         0.61                0.70                0.93
# Daily Sortino        0.99                1.15                1.52
# Daily Mean (ann.)    16.67%              19.03%              26.25%
# Daily Vol (ann.)     27.22%              27.21%              28.37%
# Daily Skew           -0.12               0.02                -0.14
# Daily Kurt           6.22                6.20                5.87
# Best Day             11.98%              11.98%              11.98%
# Worst Day            -12.86%             -12.86%             -12.86%
#
# Monthly Sharpe       0.61                0.71                0.94
# Monthly Sortino      1.15                1.40                1.86
# Monthly Mean (ann.)  16.69%              18.91%              26.28%
# Monthly Vol (ann.)   27.24%              26.74%              28.04%
# Monthly Skew         -0.10               0.03                -0.18
# Monthly Kurt         -0.22               -0.32               -0.40
# Best Month           21.66%              21.66%              21.66%
# Worst Month          -21.83%             -18.12%             -18.12%
#
# Yearly Sharpe        0.70                0.66                0.81
# Yearly Sortino       2.13                4.09                3.75
# Yearly Mean          15.96%              19.63%              29.68%
# Yearly Vol           22.82%              29.64%              36.76%
# Yearly Skew          -0.16               0.90                0.23
# Yearly Kurt          -0.71               0.35                -0.82
# Best Year            48.46%              82.31%              88.96%
# Worst Year           -25.04%             -14.07%             -26.40%
#
# Avg. Drawdown        -4.51%              -4.49%              -4.17%
# Avg. Drawdown Days   45.13               42.22               32.87
# Avg. Up Month        7.35%               7.40%               7.60%
# Avg. Down Month      -5.34%              -5.00%              -5.88%
# Win Year %           72.73%              63.64%              72.73%
# Win 12m %            74.59%              68.03%              81.15%

# %% [markdown]
# ### backtest details 15
#
# Collect detailed backtest performance per timestep of the "fast" **15-200 days** crossover moving average strategy:

# %%
    
df_bt_details_15 = bt_15.strategy.prices.to_frame(name='Rel. EQUITY')
df_bt_details_15['Abs. EQUITY'] = bt_15.strategy.values # equity per timestep
df_bt_details_15['CASH'] = bt_15.strategy.cash # cash per timestep
df_bt_details_15['POSITIONS'] = bt_15.strategy.positions # positions per timestep
df_bt_details_15['FEES'] = bt_15.strategy.fees # trading fees per timestep

df_bt_details_15
# Out:
#             Rel. EQUITY   Abs. EQUITY            CASH  POSITIONS  FEES
# 2012-12-30   100.000000  1.000000e+06  1000000.000000        0.0   0.0
# 2012-12-31   100.000000  1.000000e+06  1000000.000000        0.0   0.0
# 2013-01-02   100.000000  1.000000e+06  1000000.000000        0.0   0.0
# 2013-01-03   100.000000  1.000000e+06  1000000.000000        0.0   0.0
# 2013-01-04   100.000000  1.000000e+06  1000000.000000        0.0   0.0
# ...                 ...           ...             ...        ...   ...
# 2023-12-22   417.645162  4.176452e+06       20.625113    21600.0   0.0
# 2023-12-26   416.458671  4.164587e+06       20.625113    21600.0   0.0
# 2023-12-27   416.674355  4.166744e+06       20.625113    21600.0   0.0
# 2023-12-28   417.601986  4.176020e+06       20.625113    21600.0   0.0
# 2023-12-29   415.336879  4.153369e+06       20.625113    21600.0   0.0
#
# [2770 rows x 5 columns]

# %% [markdown]
# Visualize the monthly returns obtained by the **15-200 days** crossover moving average strategy:

# %%
plt.rcParams['figure.figsize'] = [15, 10]
fig = plt.figure()
ax = fig.add_subplot(111)

# plot heatmap of monthly returns generated by the strategy
ax = sns.heatmap(bt_15.stats.return_table, annot=True, cbar=True, vmin=-0.5, vmax=0.5)

# set axis labels
ax.set_xlabel('[month]', fontsize=10)
ax.set_ylabel('[year]', fontsize=10)

# set plot title
ax.set_title('AAPL - Monthly Returns SMAV 15-200 Strategy', fontsize=10);

# %% [markdown]
# ### backtest details 60
#
# Collect detailed backtest performance per timestep of the "fast" **60-200 days** crossover moving average strategy:

# %%
df_bt_details_60 = bt_60.strategy.prices.to_frame(name='Rel. EQUITY')
df_bt_details_60['Abs. EQUITY'] = bt_60.strategy.values # equity per timestep
df_bt_details_60['CASH'] = bt_60.strategy.cash # cash per timestep
df_bt_details_60['POSITIONS'] = bt_60.strategy.positions # positions per timestep
df_bt_details_60['FEES'] = bt_60.strategy.fees # trading fees per timestep

df_bt_details_60
# Out:
#             Rel. EQUITY   Abs. EQUITY            CASH  POSITIONS  FEES
# 2012-12-30   100.000000  1.000000e+06  1000000.000000        0.0   0.0
# 2012-12-31   100.000000  1.000000e+06  1000000.000000        0.0   0.0
# 2013-01-02   100.000000  1.000000e+06  1000000.000000        0.0   0.0
# 2013-01-03   100.000000  1.000000e+06  1000000.000000        0.0   0.0
# 2013-01-04   100.000000  1.000000e+06  1000000.000000        0.0   0.0
# ...                 ...           ...             ...        ...   ...
# 2023-12-22   541.307413  5.413074e+06      148.867528    27995.0   0.0
# 2023-12-26   539.769644  5.397696e+06      148.867528    27995.0   0.0
# 2023-12-27   540.049184  5.400492e+06      148.867528    27995.0   0.0
# 2023-12-28   541.251454  5.412515e+06      148.867528    27995.0   0.0
# 2023-12-29   538.315729  5.383157e+06      148.867528    27995.0   0.0
#
# [2770 rows x 5 columns]

# %% [markdown]
# Visualize the monthly returns obtained by the **60-200 days** crossover moving average strategy:

# %%
plt.rcParams['figure.figsize'] = [15, 10]
fig = plt.figure()
ax = fig.add_subplot(111)

# plot heatmap of monthly returns generated by the strategy
ax = sns.heatmap(bt_60.stats.return_table, annot=True, cbar=True, vmin=-0.5, vmax=0.5)

# set axis labels
ax.set_xlabel('[month]', fontsize=10)
ax.set_ylabel('[year]', fontsize=10)

# set plot title
ax.set_title('AAPL - Monthly Returns SMAV 60-200 Strategy', fontsize=10);

# %% [markdown]
# ### backtest details 60
#
# Collect detailed backtest performance per timestep of the "long only" baseline strategy:

# %%
    
df_bt_details_base = bt_base.strategy.prices.to_frame(name='Rel. EQUITY')
df_bt_details_base['Abs. EQUITY'] = bt_base.strategy.values # equity per timestep
df_bt_details_base['CASH'] = bt_base.strategy.cash # cash per timestep
df_bt_details_base['POSITIONS'] = bt_base.strategy.positions # positions per timestep
df_bt_details_base['FEES'] = bt_base.strategy.fees # trading fees per timestep

df_bt_details_base
# Out:
#             Rel. EQUITY   Abs. EQUITY            CASH  POSITIONS  FEES
# 2012-12-30   100.000000  1.000000e+06  1000000.000000        0.0   0.0
# 2012-12-31   100.000000  1.000000e+06  1000000.000000        0.0   0.0
# 2013-01-02    99.999500  9.999950e+05        5.001968    59709.0   5.0
# 2013-01-03    98.737257  9.873726e+05        5.001968    59709.0   0.0
# 2013-01-04    95.987004  9.598700e+05        5.001968    59709.0   0.0
# ...                 ...           ...             ...        ...   ...
# 2023-12-22  1154.493640  1.154494e+07        5.001968    59709.0   0.0
# 2023-12-26  1151.213818  1.151214e+07        5.001968    59709.0   0.0
# 2023-12-27  1151.810033  1.151810e+07        5.001968    59709.0   0.0
# 2023-12-28  1154.374288  1.154374e+07        5.001968    59709.0   0.0
# 2023-12-29  1148.112842  1.148113e+07        5.001968    59709.0   0.0
#
# [2770 rows x 5 columns]

# %% [markdown]
# Visualize the monthly returns obtained by the **long only** crossover moving average strategy:

# %%
plt.rcParams['figure.figsize'] = [15, 10]
fig = plt.figure()
ax = fig.add_subplot(111)

# plot heatmap of monthly returns generated by the strategy
ax = sns.heatmap(bt_base.stats.return_table, annot=True, cbar=True, vmin=-0.5, vmax=0.5)

# set axis labels
ax.set_xlabel('[month]', fontsize=10)
ax.set_ylabel('[year]', fontsize=10)

# set plot title
ax.set_title('AAPL - Monthly Returns SMAV Baseline', fontsize=10);

# %% [markdown]
# Visualize each strategie's backtest equity progression over time:

# %%
plt.rcParams['figure.figsize'] = [15, 5]
fig = plt.figure()
ax = fig.add_subplot(111)

# plot equity progression of the distinct trading strategies
ax.plot(df_bt_details_15['Rel. EQUITY'], color='C2',lw=1.0, label='15-day SMAV strategy (red)')
ax.plot(df_bt_details_60['Rel. EQUITY'], color='C1',lw=1.0, label='60-day SMAV strategy (green)')
ax.plot(df_bt_details_base['Rel. EQUITY'], color='C3',lw=1.0, label='Base SMAV strategy (purple)')

# rotate x-tick labels
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
    
# set axis labels
ax.set_xlabel('[time]', fontsize=10)
ax.set_xlim([start_date, end_date])
ax.set_ylabel('[rel. equity]', fontsize=10)

# set plot legend
plt.legend(loc="upper left", numpoints=1, fancybox=True)

# set plot title
plt.title('AAPL - Backtest % Equity Progression', fontsize=10);

# %% [markdown]
# # Part 2: Alternative data: web scraping

# %%
# !pip3 install selenium
# !pip3 install beautifulsoup4
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Collecting selenium
#   Downloading http://mirrors.aliyun.com/pypi/packages/97/e3/fd7272d6d2c49fd49a79a603cb28c8b5a71f8911861b4a0409b3c006a241/selenium-4.17.2-py3-none-any.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 1.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: urllib3<3,>=1.26 in ./qf/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.1)
# Collecting trio~=0.17 (from selenium)
#   Downloading http://mirrors.aliyun.com/pypi/packages/14/fb/9299cf74953f473a15accfdbe2c15218e766bae8c796f2567c83bae03e98/trio-0.24.0-py3-none-any.whl (460 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.2/460.2 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading http://mirrors.aliyun.com/pypi/packages/48/be/a9ae5f50cad5b6f85bd2574c2c923730098530096e170c1ce7452394d7aa/trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in ./qf/lib/python3.10/site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in ./qf/lib/python3.10/site-packages (from selenium) (4.9.0)
# Requirement already satisfied: attrs>=20.1.0 in ./qf/lib/python3.10/site-packages (from trio~=0.17->selenium) (23.2.0)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Downloading http://mirrors.aliyun.com/pypi/packages/32/46/9cb0e58b2deb7f82b84065f37f3bffeb12413f947f9388e4cac22c4621ce/sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: idna in ./qf/lib/python3.10/site-packages (from trio~=0.17->selenium) (3.6)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading http://mirrors.aliyun.com/pypi/packages/55/8b/5ab7257531a5d830fc8000c476e63c935488d74609b50f9384a643ec0a62/outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in ./qf/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup in ./qf/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.2.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading http://mirrors.aliyun.com/pypi/packages/78/58/e860788190eba3bcce367f74d29c4675466ce8dddfba85f7827588416f01/wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium)
#   Downloading http://mirrors.aliyun.com/pypi/packages/8d/59/b4572118e098ac8e46e399a1dd0f2d85403ce8bbaad9ec79373ed6badaf9/PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: h11<1,>=0.9.0 in ./qf/lib/python3.10/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Installing collected packages: sortedcontainers, wsproto, pysocks, outcome, trio, trio-websocket, selenium
# Successfully installed outcome-1.3.0.post0 pysocks-1.7.1 selenium-4.17.2 sortedcontainers-2.4.0 trio-0.24.0 trio-websocket-0.11.1 wsproto-1.2.0
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: beautifulsoup4 in ./qf/lib/python3.10/site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in ./qf/lib/python3.10/site-packages (from beautifulsoup4) (2.5)

# %%
# install chromedriver if not exists
#!brew install --cask chromedriver # for mac
# !apt install chromium-chromedriver -y # for linux
# !apt info chromium-chromedriver
# !ls /usr/lib/chromium-browser/
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# chromium-chromedriver is already the newest version (1:85.0.4183.83-0ubuntu2.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.
# Package: chromium-chromedriver
# Version: 1:85.0.4183.83-0ubuntu2.22.04.1
# Priority: optional
# Section: universe/web
# Source: chromium-browser
# Origin: Ubuntu
# Maintainer: Ubuntu Developers <ubuntu-devel-discuss@lists.ubuntu.com>
# Bugs: https://bugs.launchpad.net/ubuntu/+filebug
# Installed-Size: 77.8 kB
# Provides: chromium-driver
# Depends: chromium-browser (>= 1:85.0.4183.83-0ubuntu2.22.04.1)
# Homepage: https://chromium.googlesource.com/chromium/src/
# Download-Size: 2,308 B
# APT-Manual-Installed: yes
# APT-Sources: http://mirrors.cloud.aliyuncs.com/ubuntu jammy-updates/universe amd64 Packages
# Description: Transitional package - chromium-chromedriver -> chromium snap
#  This is a transitional dummy package. It can safely be removed.
#  .
#  chromium-chromedriver is now replaced by the chromium snap.
#
# N: There is 1 additional record. Please use the '-a' switch to see it
# chromedriver

# %%
# library to scrape webpage
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-ahm-usage')
print(options)
#service = Service(executable_path=r'/opt/homebrew/bin/chromedriver') # change to your path of chromedriver if different, for mac
service = Service(executable_path='/usr/lib/chromium-browser/chromedriver') # change to your path of chromedriver if different, for linux
driver = webdriver.Chrome(service=service, options=options)
# Out:
# <selenium.webdriver.chrome.options.Options object at 0x7f2d38e8be80>

# %%
# library to parse webpage
from bs4 import BeautifulSoup
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from time import sleep
delay = 5 #secods

# %%
# this file may need to run several time if runing on linux

url = 'https://en.wikipedia.org/wiki/Timeline_of_Apple_Inc._products'
print(url)
driver.get(url)
WebDriverWait(driver, delay)
#sleep(5)
# Out:
# https://en.wikipedia.org/wiki/Timeline_of_Apple_Inc._products
# <selenium.webdriver.support.wait.WebDriverWait (session="f02af83af630635f00d41cf186c957a1")>

# %%
html = driver.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# ![Link Name](./assets/wikitable.png)

# %%
# support function parse wikitable, because wikitable has a rowsspan and columnspan which is special.

import pandas as pd
import numpy as np

def pre_process_table(table):
    """
    INPUT:
        1. table - a bs4 element that contains the desired table: ie <table> ... </table>
    OUTPUT:
        a tuple of: 
            1. rows - a list of table rows ie: list of <tr>...</tr> elements
            2. num_rows - number of rows in the table
            3. num_cols - number of columns in the table
    Options:
        include_td_head_count - whether to use only th or th and td to count number of columns (default: False)
    """
    rows = [x for x in table.find_all('tr')]

    num_rows = len(rows)

    # get an initial column count. Most often, this will be accurate
    num_cols = max([len(x.find_all(['th','td'])) for x in rows])

    # sometimes, the tables also contain multi-colspan headers. This accounts for that:
    header_rows_set = [x.find_all(['th', 'td']) for x in rows if len(x.find_all(['th', 'td']))>num_cols/2]

    num_cols_set = []

    for header_rows in header_rows_set:
        num_cols = 0
        for cell in header_rows:
            row_span, col_span = get_spans(cell)
            num_cols+=len([cell.getText()]*col_span)

        num_cols_set.append(num_cols)

    num_cols = max(num_cols_set)

    return (rows, num_rows, num_cols)


def get_spans(cell):
        """
        INPUT:
            1. cell - a <td>...</td> or <th>...</th> element that contains a table cell entry
        OUTPUT:
            1. a tuple with the cell's row and col spans
        """
        if cell.has_attr('rowspan'):
            rep_row = int(cell.attrs['rowspan'])
        else: # ~cell.has_attr('rowspan'):
            rep_row = 1
        if cell.has_attr('colspan'):
            rep_col = int(cell.attrs['colspan'])
        else: # ~cell.has_attr('colspan'):
            rep_col = 1 

        return (rep_row, rep_col)

def process_rows(rows, num_rows, num_cols):
    """
    INPUT:
        1. rows - a list of table rows ie <tr>...</tr> elements
    OUTPUT:
        1. data - a Pandas dataframe with the html data in it
    """
    data = pd.DataFrame(np.ones((num_rows, num_cols))*np.nan)
    for i, row in enumerate(rows):
        try:
            col_stat = data.iloc[i,:][data.iloc[i,:].isnull()].index[0]
        except IndexError:
            print(i, row)

        for j, cell in enumerate(row.find_all(['td', 'th'])):
            rep_row, rep_col = get_spans(cell)

            #print("cols {0} to {1} with rep_col={2}".format(col_stat, col_stat+rep_col, rep_col))
            #print("\trows {0} to {1} with rep_row={2}".format(i, i+rep_row, rep_row))

            #find first non-na col and fill that one
            while any(data.iloc[i,col_stat:col_stat+rep_col].notnull()):
                col_stat+=1

            data.iloc[i:i+rep_row,col_stat:col_stat+rep_col] = cell.getText()
            if col_stat<data.shape[1]-1:
                col_stat+=rep_col

    return data

# %%
# parse to get detailed data in wikitable

tables = []
for table in soup.find_all('table'):
    if not 'wikitable' in table.get('class'):
        continue
    if not "released" in table.text.lower():
        continue
    tables.append(table)

dfs = []
i = 0
for table in tables:
    i = i + 1
    #print(table.text)
    rows, num_rows, num_cols = pre_process_table(table)
    df1 = process_rows(rows, num_rows, num_cols)
    dfs.append(df1)
    
df_timeline = pd.concat(dfs, ignore_index=True)
df_timeline = df_timeline.rename(columns={0: 'released', 1:'model', 2:'family', 3:'discounted'})
#print(df_timeline)
df_timeline['released'] = df_timeline['released'].str.strip()
df_timeline['model'] = df_timeline['model'].str.strip()
df_timeline['family'] = df_timeline['family'].str.strip()
df_timeline['discounted'] = df_timeline['discounted'].str.strip()
df_timeline
# Out:
# /tmp/ipykernel_2948/43173894.py:85: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Released
# ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.iloc[i:i+rep_row,col_stat:col_stat+rep_col] = cell.getText()
# /tmp/ipykernel_2948/43173894.py:85: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Model
# ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.iloc[i:i+rep_row,col_stat:col_stat+rep_col] = cell.getText()
# /tmp/ipykernel_2948/43173894.py:85: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Family
# ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.iloc[i:i+rep_row,col_stat:col_stat+rep_col] = cell.getText()
# /tmp/ipykernel_2948/43173894.py:85: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Discontinued
# ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.iloc[i:i+rep_row,col_stat:col_stat+rep_col] = cell.getText()
#              released                                            model  \
# 0            Released                                            Model
# 1      April 11, 1976                                          Apple I
# 2        June 1, 1977                                         Apple II
# 3        June 1, 1978                                          Disk II
# 4        June 1, 1979                                    Apple II Plus
# ..                ...                                              ...
# 710  November 7, 2023                         iMac (24-inch, M3, 2023)
# 711  November 7, 2023  MacBook Pro  (M3/M3 Pro/M3 Max) (14-inch, 2023)
# 712  November 7, 2023      MacBook Pro (M3 Pro/M3 Max) (16-inch, 2023)
# 713          Released                                            Model
# 714  February 2, 2024                                 Apple Vision Pro
#
#                family          discounted
# 0              Family        Discontinued
# 1             Apple I  September 30, 1977
# 2            Apple II         May 1, 1979
# 3              Drives         May 1, 1984
# 4     Apple II series    December 1, 1982
# ..                ...                 ...
# 710              iMac             current
# 711       MacBook Pro             current
# 712       MacBook Pro             current
# 713            Family        Discontinued
# 714  Apple Vision Pro             current
#
# [715 rows x 4 columns]

# %%
# support function to clean "released" and "discounted" data
import datetime
def process_date(d):
    try:
        if "," in d:
            try:
                dt = datetime.datetime.strptime(d, '%B %d, %Y')
                return dt
            except ValueError as e:
                dt = datetime.datetime.strptime(d, '%B, %Y')
                return dt
        else:
            try:
                dt = datetime.datetime.strptime(d, '%B %Y')
                return dt
            except ValueError as e:
                dt = datetime.datetime.strptime(d, '%Y')
                return dt
    except Exception as e:
        return None

print(process_date('September 21, 2018'))
print(process_date('September 2018'))
print(process_date('August, 1987'))
# Out:
# 2018-09-21 00:00:00
# 2018-09-01 00:00:00
# 1987-08-01 00:00:00

# %%
df_timeline['released_dt'] = df_timeline['released'].apply(process_date)
df_timeline['discounted_dt'] = df_timeline['discounted'].apply(process_date)
df_timeline
# Out:
#              released                                            model  \
# 0            Released                                            Model
# 1      April 11, 1976                                          Apple I
# 2        June 1, 1977                                         Apple II
# 3        June 1, 1978                                          Disk II
# 4        June 1, 1979                                    Apple II Plus
# ..                ...                                              ...
# 710  November 7, 2023                         iMac (24-inch, M3, 2023)
# 711  November 7, 2023  MacBook Pro  (M3/M3 Pro/M3 Max) (14-inch, 2023)
# 712  November 7, 2023      MacBook Pro (M3 Pro/M3 Max) (16-inch, 2023)
# 713          Released                                            Model
# 714  February 2, 2024                                 Apple Vision Pro
#
#                family          discounted released_dt discounted_dt
# 0              Family        Discontinued         NaT           NaT
# 1             Apple I  September 30, 1977  1976-04-11    1977-09-30
# 2            Apple II         May 1, 1979  1977-06-01    1979-05-01
# 3              Drives         May 1, 1984  1978-06-01    1984-05-01
# 4     Apple II series    December 1, 1982  1979-06-01    1982-12-01
# ..                ...                 ...         ...           ...
# 710              iMac             current  2023-11-07           NaT
# 711       MacBook Pro             current  2023-11-07           NaT
# 712       MacBook Pro             current  2023-11-07           NaT
# 713            Family        Discontinued         NaT           NaT
# 714  Apple Vision Pro             current  2024-02-02           NaT
#
# [715 rows x 6 columns]

# %%
# check null value
df_timeline[df_timeline['released_dt'].isnull()]
# Out:
#      released  model  family    discounted released_dt discounted_dt
# 0    Released  Model  Family  Discontinued         NaT           NaT
# 10   Released  Model  Family  Discontinued         NaT           NaT
# 25   Released  Model  Family  Discontinued         NaT           NaT
# 41   Released  Model  Family  Discontinued         NaT           NaT
# 53   Released  Model  Family  Discontinued         NaT           NaT
# 66   Released  Model  Family  Discontinued         NaT           NaT
# 76   Released  Model  Family  Discontinued         NaT           NaT
# 82   Released  Model  Family  Discontinued         NaT           NaT
# 94   Released  Model  Family  Discontinued         NaT           NaT
# 100  Released  Model  Family  Discontinued         NaT           NaT
# 114  Released  Model  Family  Discontinued         NaT           NaT
# 127  Released  Model  Family  Discontinued         NaT           NaT
# 167  Released  Model  Family  Discontinued         NaT           NaT
# 192  Released  Model  Family  Discontinued         NaT           NaT
# 213  Released  Model  Family  Discontinued         NaT           NaT
# 234  Released  Model  Family  Discontinued         NaT           NaT
# 255  Released  Model  Family  Discontinued         NaT           NaT
# 261  Released  Model  Family  Discontinued         NaT           NaT
# 271  Released  Model  Family  Discontinued         NaT           NaT
# 277  Released  Model  Family  Discontinued         NaT           NaT
# 285  Released  Model  Family  Discontinued         NaT           NaT
# 294  Released  Model  Family  Discontinued         NaT           NaT
# 305  Released  Model  Family  Discontinued         NaT           NaT
# 320  Released  Model  Family  Discontinued         NaT           NaT
# 328  Released  Model  Family  Discontinued         NaT           NaT
# 343  Released  Model  Family  Discontinued         NaT           NaT
# 356  Released  Model  Family  Discontinued         NaT           NaT
# 381  Released  Model  Family  Discontinued         NaT           NaT
# 407  Released  Model  Family  Discontinued         NaT           NaT
# 427  Released  Model  Family  Discontinued         NaT           NaT
# 442  Released  Model  Family  Discontinued         NaT           NaT
# 467  Released  Model  Family  Discontinued         NaT           NaT
# 487  Released  Model  Family  Discontinued         NaT           NaT
# 502  Released  Model  Family  Discontinued         NaT           NaT
# 532  Released  Model  Family  Discontinued         NaT           NaT
# 554  Released  Model  Family  Discontinued         NaT           NaT
# 579  Released  Model  Family  Discontinued         NaT           NaT
# 597  Released  Model  Family  Discontinued         NaT           NaT
# 623  Released  Model  Family  Discontinued         NaT           NaT
# 649  Released  Model  Family  Discontinued         NaT           NaT
# 673  Released  Model  Family  Discontinued         NaT           NaT
# 693  Released  Model  Family  Discontinued         NaT           NaT
# 713  Released  Model  Family  Discontinued         NaT           NaT

# %%
df_timeline = df_timeline[df_timeline['released_dt'].notnull()]
df_timeline
# Out:
#              released                                            model  \
# 1      April 11, 1976                                          Apple I
# 2        June 1, 1977                                         Apple II
# 3        June 1, 1978                                          Disk II
# 4        June 1, 1979                                    Apple II Plus
# 5        June 1, 1979                                Apple II EuroPlus
# ..                ...                                              ...
# 709  November 1, 2023                             Apple Pencil (USB-C)
# 710  November 7, 2023                         iMac (24-inch, M3, 2023)
# 711  November 7, 2023  MacBook Pro  (M3/M3 Pro/M3 Max) (14-inch, 2023)
# 712  November 7, 2023      MacBook Pro (M3 Pro/M3 Max) (16-inch, 2023)
# 714  February 2, 2024                                 Apple Vision Pro
#
#                family          discounted released_dt discounted_dt
# 1             Apple I  September 30, 1977  1976-04-11    1977-09-30
# 2            Apple II         May 1, 1979  1977-06-01    1979-05-01
# 3              Drives         May 1, 1984  1978-06-01    1984-05-01
# 4     Apple II series    December 1, 1982  1979-06-01    1982-12-01
# 5     Apple II series    December 1, 1982  1979-06-01    1982-12-01
# ..                ...                 ...         ...           ...
# 709              iPad             current  2023-11-01           NaT
# 710              iMac             current  2023-11-07           NaT
# 711       MacBook Pro             current  2023-11-07           NaT
# 712       MacBook Pro             current  2023-11-07           NaT
# 714  Apple Vision Pro             current  2024-02-02           NaT
#
# [672 rows x 6 columns]

# %%
df_timeline = df_timeline[['family', 'model', 'released_dt', 'discounted_dt']]
df_timeline
# Out:
#                family                                            model  \
# 1             Apple I                                          Apple I
# 2            Apple II                                         Apple II
# 3              Drives                                          Disk II
# 4     Apple II series                                    Apple II Plus
# 5     Apple II series                                Apple II EuroPlus
# ..                ...                                              ...
# 709              iPad                             Apple Pencil (USB-C)
# 710              iMac                         iMac (24-inch, M3, 2023)
# 711       MacBook Pro  MacBook Pro  (M3/M3 Pro/M3 Max) (14-inch, 2023)
# 712       MacBook Pro      MacBook Pro (M3 Pro/M3 Max) (16-inch, 2023)
# 714  Apple Vision Pro                                 Apple Vision Pro
#
#     released_dt discounted_dt
# 1    1976-04-11    1977-09-30
# 2    1977-06-01    1979-05-01
# 3    1978-06-01    1984-05-01
# 4    1979-06-01    1982-12-01
# 5    1979-06-01    1982-12-01
# ..          ...           ...
# 709  2023-11-01           NaT
# 710  2023-11-07           NaT
# 711  2023-11-07           NaT
# 712  2023-11-07           NaT
# 714  2024-02-02           NaT
#
# [672 rows x 4 columns]

# %%
df_timeline = df_timeline.sort_values(by=['family', 'released_dt', 'model'], ascending=False)
df_timeline
# Out:
#                family                                           model  \
# 337  iPod accessories                                       Nike+iPod
# 330  iPod accessories                               iPod Radio Remote
# 605        iPod Touch                     iPod Touch (7th generation)
# 512        iPod Touch  iPod Touch (6th generation) (32 GB and 128 GB)
# 513        iPod Touch   iPod Touch (6th generation) (16 GB and 64 GB)
# ..                ...                                             ...
# 389           AirPort               AirPort Extreme 802.11n (3rd gen)
# 266           AirPort                   AirPort (802.11b, "Graphite")
# 42              68000                                    Macintosh XL
# 26              68000                                    Apple Lisa 2
# 22              68000                                   Apple Lisa[2]
#
#     released_dt discounted_dt
# 337  2006-07-13    2014-01-01
# 330  2006-01-10    2009-06-25
# 605  2019-05-28    2022-05-10
# 512  2015-07-15    2019-05-28
# 513  2015-07-15    2017-07-27
# ..          ...           ...
# 389  2009-03-03    2009-10-20
# 266  1999-07-21    2001-11-13
# 42   1985-01-01    1985-04-01
# 26   1984-01-01    1986-08-01
# 22   1983-01-19    1984-01-01
#
# [672 rows x 4 columns]

# %%
df_timeline['family'].unique()
# Out:
# array(['iPod accessories', 'iPod Touch', 'iPod Shuffle', 'iPod Nano',
#        'iPod Mini', 'iPod Classic', 'iPhone accessories', 'iPhone',
#        'iPad', 'iMac', 'iBook', 'eMac', 'Xserve', 'Workgroup Server',
#        'StyleWriter', 'Speakers', 'Scanner', 'QuickTake', 'Quadra',
#        'Printers', 'PowerCD', 'PowerBook G4', 'PowerBook G3',
#        'PowerBook Duo', 'PowerBook 500', 'PowerBook 100', 'PowerBook',
#        'Power Macintosh', 'Portable', 'Pointing devices', 'Pippin',
#        'Newton', 'Networking', 'Network Server', 'Modems',
#        'Macintosh Server', 'Macintosh LC', 'MacBook Pro', 'MacBook Air',
#        'MacBook', 'Mac Studio', 'Mac Pro', 'Mac Mini', 'Mac II',
#        'LaserWriter', 'LC', 'Keyboards', 'Input Device Accessories',
#        'ImageWriter', 'Headphones', 'Drives', 'Displays', 'Display',
#        'Compact', 'Cleaning aid', 'Centris', 'Apple Watch',
#        'Apple Vision Pro', 'Apple TV', 'Apple III', 'Apple II series',
#        'Apple II', 'Apple I', 'AirPort, drives', 'AirPort Express',
#        'AirPort', '68000'], dtype=object)

# %%
df_timeline[df_timeline['family'] == 'iPhone']
# Out:
#      family                            model released_dt discounted_dt
# 706  iPhone                iPhone 15 Pro Max  2023-09-22           NaT
# 705  iPhone                    iPhone 15 Pro  2023-09-22           NaT
# 704  iPhone                   iPhone 15 Plus  2023-09-22           NaT
# 703  iPhone                        iPhone 15  2023-09-22           NaT
# 687  iPhone                   iPhone 14 Plus  2022-10-07           NaT
# ..      ...                              ...         ...           ...
# 369  iPhone                 iPhone 3G (8 GB)  2008-07-11    2010-06-07
# 370  iPhone                iPhone 3G (16 GB)  2008-07-11    2009-06-08
# 361  iPhone  iPhone (1st generation) (16 GB)  2008-02-05    2008-07-11
# 346  iPhone   iPhone (1st generation) (8 GB)  2007-06-29    2008-07-11
# 345  iPhone   iPhone (1st generation) (4 GB)  2007-06-29    2007-09-05
#
# [66 rows x 4 columns]

# %% [markdown]
# # plot iphone release data by comparing to stock price

# %%
plt.rcParams['figure.figsize'] = [15, 5]
fig, ax = plt.subplots(ncols=1, nrows=3)

ax[0].plot(df_signal['SIGNAL_15'], lw=1.0, color='C2', label='SMAV 15 (red)')
ax[1].plot(df_signal['SIGNAL_60'], lw=1.0, color='C1', label='SMAV 60 (green)')
ax[2].plot(df_signal['SIGNAL_BASE'], lw=1.0, color='C3', label='BASE (purple)')
    
# set axis labels
plt.xlabel('[time]', fontsize=10)
ax[0].set_xlim([start_date, end_date])
ax[0].set_ylabel('[smav 15 signal]', fontsize=10)
ax[1].set_xlim([start_date, end_date])
ax[1].set_ylabel('[smav 60 signal]', fontsize=10)
ax[2].set_xlim([start_date, end_date])
ax[2].set_ylabel('[base signal]', fontsize=10)


# add iphone release data
ax[0].vlines(x = df_timeline[df_timeline['family'] == 'iPhone']['released_dt'].values, 
           ymin = -0.5, ymax = 0.5,
           colors = 'blue',
           label = 'iPhone release date')
ax[1].vlines(x = df_timeline[df_timeline['family'] == 'iPhone']['released_dt'].values, 
           ymin = -0.5, ymax = 0.5,
           colors = 'blue',
           label = 'iPhone release date')
ax[2].vlines(x = df_timeline[df_timeline['family'] == 'iPhone']['released_dt'].values, 
           ymin = -0.5, ymax = 0.5,
           colors = 'blue',
           label = 'iPhone release date')

# rotate the x-axis labels
'''
for tick in ax[0].get_xticklabels():
    tick.set_rotation(45)
    
for tick in ax[1].get_xticklabels():
    tick.set_rotation(45)
    
for tick in ax[2].get_xticklabels():
    tick.set_rotation(45)
'''

# set plot title
ax[0].set_title('AAPL - 15 days Crossover Moving Average Trading Signals', fontsize=10)
ax[1].set_title('AAPL - 60 days Crossover Moving Average Trading Signals', fontsize=10)
ax[2].set_title('AAPL - Baseline Buy and Hold Trading Signals', fontsize=10)

# reset plot layout
plt.tight_layout()

# %%
plt.rcParams['figure.figsize'] = [15, 5]
fig = plt.figure()
ax = fig.add_subplot(111)

# plot adjusted closing prices and moving averages
ax.plot(df_smav['Adj Close'], lw=1.0, color='#9b59b6', label='Closing Prices (purple)')
ax.plot(df_smav['SMAV_15'], color='C1',lw=1.0, label='15-day MAV (green)')
ax.plot(df_smav['SMAV_60'], color='C1',lw=1.0, label='60-day MAV (red)')
ax.plot(df_smav['SMAV_200'], color='C4', lw=1.0, label='200-day MAV (yellow)')

# add iphone release data
plt.vlines(x = df_timeline[df_timeline['family'] == 'iPhone']['released_dt'].values, 
           ymin = 0, ymax = 150,
           colors = 'blue',
           label = 'iPhone release date')

# rotate x-tick labels
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
    
# set axis labels
ax.set_xlabel('[time]', fontsize=10)
ax.set_xlim([start_date, end_date])
ax.set_ylabel('[market price]', fontsize=10)

# set plot legend
plt.legend(loc="upper left", numpoints=1, fancybox=True)

# set plot title
plt.title('AAPL - Daily Historical Stock Closing Prices', fontsize=10);

# %%
plt.rcParams['figure.figsize'] = [15, 5]
fig = plt.figure()
ax = fig.add_subplot(111)

# plot equity progression of the distinct trading strategies
ax.plot(df_bt_details_15['Rel. EQUITY'], color='C2',lw=1.0, label='15-day SMAV strategy (red)')
ax.plot(df_bt_details_60['Rel. EQUITY'], color='C1',lw=1.0, label='60-day SMAV strategy (green)')
ax.plot(df_bt_details_base['Rel. EQUITY'], color='C3',lw=1.0, label='Base SMAV strategy (purple)')

# add iphone release data
plt.vlines(x = df_timeline[df_timeline['family'] == 'iPhone']['released_dt'].values, 
           ymin = 0, ymax = 1000,
           colors = 'blue',
           label = 'iPhone release date')


# rotate x-tick labels
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
    
# set axis labels
ax.set_xlabel('[time]', fontsize=10)
ax.set_xlim([start_date, end_date])
ax.set_ylabel('[rel. equity]', fontsize=10)

# set plot legend
plt.legend(loc="upper left", numpoints=1, fancybox=True)

# set plot title
plt.title('AAPL - Backtest % Equity Progression', fontsize=10)

plt.show()

# %% [markdown]
# # Part 3: future work

# %%
# this is just a demo 
# think about where to improve
